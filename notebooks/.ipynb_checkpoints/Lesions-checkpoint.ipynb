# %%
import jupyter
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import torch as tor
import torchvision as tcv
import pandas as pd
import imageio
import seaborn as sns
import glob2
import scipy

# %%
df = pd.read_csv('data/lesions/HAM10000_metadata', compression='infer')
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset
# 0  vidir_modern
# 1  vidir_modern
# 2  vidir_modern
# 3  vidir_modern
# 4  vidir_modern

# %%
sns.displot(df.age)
sns.displot(df.sex)
sns.displot(df.localization)

# %%
dataset = tcv.datasets.ImageFolder("data/lesions")
plt.imshow(dataset[0][0])
plt.axis('off')
plt.show()

plt.imshow(dataset[1][0])
plt.axis('off')
plt.show()

plt.imshow(dataset[2][0])
plt.axis('off')
plt.show()
